# %%
#mypro on adaptive network, rew= 0.2, tmax=4000,N0=10000,N=100000,k=10,mu= 0.002,ka=0.5,gama=.98,phi=0.2,forward & backward (adaptsis.cpp)
#7.4.1401

import numpy as np
import matplotlib.pylab as plt

plt.rcParams["font.family"] ="Times New Roman"
#loading data as a matrix
fw=np.loadtxt('Inf-forw rew0.2.txt')
bw = np.loadtxt('Inf-back rew0.2.txt')
# each colomn as an array
betaf=fw[:,0]         
rof=fw[:,1]
betab=bw[:,0]
rob=bw[:,1]
#print(fee)
# Plot
fig, axes = plt.subplots(figsize=(12,8))

plt.plot(betaf,rof ,  linewidth = 2.5,linestyle='--',marker='o',markersize=11, color='gold', label = "$forward$")
plt.plot(betab , rob, linewidth = 2.5,linestyle =':',marker='v',markersize=11,color="darkorchid", label ="$backward$")

plt.legend(loc="lower right", fontsize=20)
#plt.grid(color = 'C7', alpha=0.5, linestyle = ':', linewidth = 0.5)
plt.xlim([0,0.005])
plt.ylim([0,1])

plt.xticks([0.002 * i for i in range(11)])
plt.yticks([0.1 * i for i in range(11)])

plt.xlabel(r'$\beta $' ,fontsize=30)
plt.ylabel(r'$\rho $' , fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.xlim(xmin=0)
plt.ylim(ymin=0)

plt.savefig('mypro adapt rew0.2.png')
plt.savefig('mypro adapt rew0.2.pdf')

# %%
#mypro on adaptive network, rew= 0.04, tmax=4000,N0=10000,N=100000,k=10,mu= 0.002,ka=0.5,gama=.98,phi=0.2,forward & backward (adaptsis.cpp)
#7.4.1401

import numpy as np
import matplotlib.pylab as plt

plt.rcParams["font.family"] ="Times New Roman"
#loading data as a matrix
fw=np.loadtxt('Inf-forw rew0.04.txt')
bw = np.loadtxt('Inf-back rew0.04.txt')
# each colomn as an array
betaf=fw[:,0]         
rof=fw[:,1]
betab=bw[:,0]
rob=bw[:,1]
#print(fee)
# Plot
fig, axes = plt.subplots(figsize=(12,8))

plt.plot(betaf,rof ,  linewidth = 2.5,linestyle='--',marker='o',markersize=11, color='gold', label = "$forward$")
plt.plot(betab , rob, linewidth = 2.5,linestyle =':',marker='v',markersize=11,color="darkorchid", label ="$backward$")

plt.legend(loc="lower right", fontsize=20)
#plt.grid(color = 'C7', alpha=0.5, linestyle = ':', linewidth = 0.5)
plt.xlim([0,0.005])
plt.ylim([0,1])

plt.xticks([0.002 * i for i in range(11)])
plt.yticks([0.1 * i for i in range(11)])

plt.xlabel(r'$\beta $' ,fontsize=30)
plt.ylabel(r'$\rho $' , fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.xlim(xmin=0)
plt.ylim(ymin=0)

plt.savefig('mypro adapt rew0.04.png')
plt.savefig('mypro adapt rew0.04.pdf')

# %%
#mypro on adaptive network, rew= 0.2, tmax=4000,N0=10000,N=100000,k=10,mu= 0.002,ka=0.5,gama=.98,phi=0.2,forward & backward (adaptsis.cpp)
#7.4.1401

import numpy as np
import matplotlib.pylab as plt

plt.rcParams["font.family"] ="Times New Roman"
#loading data as a matrix
fw=np.loadtxt('Inf-forw rew0.0.txt')
#bw = np.loadtxt('Inf-back rew0.2.txt')
# each colomn as an array
betaf=fw[:,0]         
rof=fw[:,1]
#betab=bw[:,0]
#rob=bw[:,1]
#print(fee)
# Plot
fig, axes = plt.subplots(figsize=(12,8))

plt.plot(betaf,rof ,  linewidth = 2.5,linestyle='--',marker='o',markersize=11, color='gold', label = "$forward$")
#plt.plot(betab , rob, linewidth = 2.5,linestyle =':',marker='v',markersize=11,color="darkorchid", label ="$backward$")

plt.legend(loc="lower right", fontsize=20)
#plt.grid(color = 'C7', alpha=0.5, linestyle = ':', linewidth = 0.5)
plt.xlim([0,0.005])
plt.ylim([0,1])

plt.xticks([0.002 * i for i in range(11)])
plt.yticks([0.1 * i for i in range(11)])

plt.xlabel(r'$\beta $' ,fontsize=30)
plt.ylabel(r'$\rho $' , fontsize=30)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.xlim(xmin=0)
plt.ylim(ymin=0)

plt.savefig('mypro adapt rew0.0.png')
plt.savefig('mypro adapt rew0.0.pdf')
